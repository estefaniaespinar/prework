# %%
#1. Import the choice function of the random module.¶
#2. Create a list that includes the 3 possible gesture options of the game: 'rock', 'paper' or 'scissors'. Store the list in a variable called gestures.¶

import random 

gestures=["rock","paper","scissors"]

#3. Create a variable called n_rounds to store the maximum number of rounds to play in a game.¶

n_rounds=5

#4. Create a variable called rounds_to_win to store the number of rounds that a player must win to win the game.¶

rounds_to_win=(n_rounds/2)+0.5

#5. Create two variables to store the number of rounds that the computer and the player have won. Call these variables cpu_score and player_score.

cpu_score=0
player_score=0

#6. Define a function that randomly returns one of the 3 gesture options.¶

auto=(random.choice(gestures))

#7. Define a function that asks the player which is the gesture he or she wants to show: 'rock', 'paper' or 'scissors'.¶

promt="Choose one of the following gestures: Rock, paper or scissors: "
promt_1="You can only insert one of the following gestures: rock, paper or scissors: "

which_one=input(promt)

while which_one not in ("paper","rock","scissors"):
    which_one=input(promt_1)

if which_one in ("paper","rock","scissors"):
    print("You have chosen:",which_one)

#8. Define a function that checks who won a round. The function should return 0 if there is a tie, 1 if the computer wins and 2 if the player wins.

who_won="idk"

if (which_one == "paper" and auto == "paper") or (which_one == "rock" and auto == "rock") or (which_one == "scissors" and auto == "scissors"):
    who_won=0
elif (which_one == "rock" and auto == "paper") or (which_one == "paper" and auto == "scissors") or (which_one == "scissors" and auto == "rock"):
    who_won=2
elif (which_one == "rock" and auto == "scissors") or (which_one == "paper" and auto == "rock") or (which_one == "scissors" and auto == "paper"):
    who_won=1
    

#9. Define a function that prints the choice of the computer, the choice of the player and a message that announces who won the current round.

print(which_one)
print(auto)
if who_won == 0:
    print("Tie.")
elif who_won == 1:
    print("The player won.")
elif who_won ==2:
    print("The computer won.")
    
#10. Now it's time to code the execution of the game using the functions and variables you defined above.¶

import random 

gestures=["rock","paper","scissors"]
n_rounds=5
rounds_to_win=(n_rounds/2)+0.5
cpu_score=0
player_score=0
auto=(random.choice(gestures))
promt="Choose one of the following gestures: Rock, paper or scissors: "
promt_1="You can only insert one of the following gestures: rock, paper or scissors: "
who_won="idk"
rounds=0
which_one=input(promt)


while (cpu_score < rounds_to_win) and (player_score < rounds_to_win) and (rounds<n_rounds):
    rounds+=1
    print("Round:",rounds)
    which_one=input(promt)
    while which_one not in ("paper","rock","scissors"):
        which_one=input(promt_1)
        if which_one in ("paper","rock","scissors"):
            print("You have chosen:",which_one)
    auto=(random.choice(gestures))
    print("The machine has choosen:",auto)
    if (which_one == "paper" and auto == "paper") or (which_one == "rock" and auto == "rock") or (which_one == "scissors" and auto == "scissors"):
        who_won=0
    elif (which_one == "rock" and auto == "paper") or (which_one == "paper" and auto == "scissors") or (which_one == "scissors" and auto == "rock"):
        who_won=2
    elif (which_one == "rock" and auto == "scissors") or (which_one == "paper" and auto == "rock") or (which_one == "scissors" and auto == "paper"):
        who_won=1  
    if who_won == 0:
        print("Tie.")
    elif who_won == 1:
        print("The player won.")
        player_score+=1
        print("Player score:",player_score)
        print("Machine score:",cpu_score)
    elif who_won == 2:
        print("The machine won.")
        cpu_score+=1
        print("Machine score:",cpu_score)
        print("Player score:",player_score)
        
print("FINAL SCORE:")
print("Machine score is",cpu_score)
print("Player score is",player_score)
        
if cpu_score >= rounds_to_win:
    print("The winner is the machine.")
elif player_score >= rounds_to_win:
    print("The winner is the player.")
elif (cpu_score and player_score) < rounds_to_win:
    print("Sorry, you needed to win",int(rounds_to_win),"to win the game. The final score is: tie. Try again!")
# Out:
# Choose one of the following gestures: Rock, paper or scissors: paper
# You have chosen: paper
# paper
# paper
# Tie.
# Choose one of the following gestures: Rock, paper or scissors: paper
# Round: 1
# Choose one of the following gestures: Rock, paper or scissors: paper
# The machine has choosen: scissors
# The machine won.
# Machine score: 1
# Player score: 0
# Round: 2
# Choose one of the following gestures: Rock, paper or scissors: paper
# The machine has choosen: scissors
# The machine won.
# Machine score: 2
# Player score: 0
# Round: 3
# Choose one of the following gestures: Rock, paper or scissors: paper
# The machine has choosen: scissors
# The machine won.
# Machine score: 3
# Player score: 0
# FINAL SCORE:
# Machine score is 3
# Player score is 0
# The winner is the machine.
